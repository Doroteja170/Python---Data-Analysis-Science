# %%
pip install fastf1
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 8.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import fastf1

# %%
import os
cache_folder='cache_folder'
if not os.path.exists(cache_folder):
    os.makedirs(cache_folder)
fastf1.Cache.enable_cache(cache_folder)

# %%
from fastf1.events import get_event_schedule
schedule = get_event_schedule(2025)
schedule.head()
# Out:
#    RoundNumber    Country   Location  \
# 0            0    Bahrain     Sakhir
# 1            1  Australia  Melbourne
# 2            2      China   Shanghai
# 3            3      Japan     Suzuka
# 4            4    Bahrain     Sakhir
#
#                                    OfficialEventName  EventDate  \
# 0           FORMULA 1 ARAMCO PRE-SEASON TESTING 2025 2025-02-28
# 1  FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ... 2025-03-16
# 2         FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025 2025-03-23
# 3         FORMULA 1 LENOVO JAPANESE GRAND PRIX 2025  2025-04-06
# 4         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2025 2025-04-13
#
#                EventName        EventFormat    Session1  \
# 0     Pre-Season Testing            testing  Practice 1
# 1  Australian Grand Prix       conventional  Practice 1
# 2     Chinese Grand Prix  sprint_qualifying  Practice 1
# 3    Japanese Grand Prix       conventional  Practice 1
# 4     Bahrain Grand Prix       conventional  Practice 1
#
# ...

# %%
session=fastf1.get_session(2025,'Australia','Q')
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '81', '1', '63', '22', '23', '16', '44', '10', '55', '6', '14', '18', '7', '5', '12', '27', '30', '31', '87']

# %%
aus_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
aus_quali['GrandPrix']='Australian Grand Prix'
aus_quali.head()
# Out:
#     Position Abbreviation         TeamName                     Q1  \
# 4        1.0          NOR          McLaren 0 days 00:01:15.912000
# 81       2.0          PIA          McLaren 0 days 00:01:16.062000
# 1        3.0          VER  Red Bull Racing 0 days 00:01:16.018000
# 63       4.0          RUS         Mercedes 0 days 00:01:15.971000
# 22       5.0          TSU     Racing Bulls 0 days 00:01:16.225000
#
#                        Q2                     Q3              GrandPrix
# 4  0 days 00:01:15.415000 0 days 00:01:15.096000  Australian Grand Prix
# 81 0 days 00:01:15.468000 0 days 00:01:15.180000  Australian Grand Prix
# 1  0 days 00:01:15.565000 0 days 00:01:15.481000  Australian Grand Prix
# 63 0 days 00:01:15.798000 0 days 00:01:15.546000  Australian Grand Prix
# 22 0 days 00:01:16.009000 0 days 00:01:15.670000  Australian Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_aus_quali = laps[['Driver','LapNumber' ,'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_aus_quali['GrandPrix']='Australian Grand Prix'
sector_times_aus_quali
# Out:
#     Driver  LapNumber                LapTime            Sector1Time  \
# 1      NOR        2.0 0 days 00:01:16.003000 0 days 00:00:26.383000
# 4      NOR        5.0 0 days 00:01:15.912000 0 days 00:00:26.463000
# 9      NOR       10.0 0 days 00:01:15.556000 0 days 00:00:26.104000
# 12     NOR       13.0 0 days 00:01:15.415000 0 days 00:00:26.194000
# 15     NOR       16.0 0 days 00:01:15.921000 0 days 00:00:26.127000
# ..     ...        ...                    ...                    ...
# 278    HUL        8.0 0 days 00:01:16.579000 0 days 00:00:26.656000
# 281    LAW        2.0 0 days 00:01:17.094000 0 days 00:00:26.819000
# 288    OCO        2.0 0 days 00:01:17.517000 0 days 00:00:27.066000
# 291    OCO        5.0 0 days 00:01:17.147000 0 days 00:00:26.686000
# 294    OCO        8.0 0 days 00:01:17.686000 0 days 00:00:26.678000
#
#                Sector2Time            Sector3Time              GrandPrix
# 1   0 days 00:00:17.285000 0 days 00:00:32.335000  Australian Grand Prix
# ...

# %%
session=fastf1.get_session(2025,'Australia','R')
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 4 completed the race distance 00:00.022000 before the recorded end of the session.
# ...

# %%
aus_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
aus_race['GrandPrix']='Australian Grand Prix'
aus_race.head()
# Out:
#     Position Abbreviation         TeamName                   Time    Status  \
# 4        1.0          NOR          McLaren 0 days 01:42:06.304000  Finished
# 1        2.0          VER  Red Bull Racing 0 days 00:00:00.895000  Finished
# 63       3.0          RUS         Mercedes 0 days 00:00:08.481000  Finished
# 12       4.0          ANT         Mercedes 0 days 00:00:10.135000  Finished
# 23       5.0          ALB         Williams 0 days 00:00:12.773000  Finished
#
#                 GrandPrix
# 4   Australian Grand Prix
# 1   Australian Grand Prix
# 63  Australian Grand Prix
# 12  Australian Grand Prix
# 23  Australian Grand Prix

# %%
session=fastf1.get_session(2025,'China','Q')
session.load()
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '63', '4', '1', '44', '16', '6', '12', '22', '23', '31', '27', '14', '18', '55', '10', '87', '7', '5', '30']

# %%
china_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
china_quali['GrandPrix']='Chinese Grand Prix'
china_quali.head()
# Out:
#     Position Abbreviation         TeamName                     Q1  \
# 81       1.0          PIA          McLaren 0 days 00:01:31.591000
# 63       2.0          RUS         Mercedes 0 days 00:01:31.295000
# 4        3.0          NOR          McLaren 0 days 00:01:30.983000
# 1        4.0          VER  Red Bull Racing 0 days 00:01:31.424000
# 44       5.0          HAM          Ferrari 0 days 00:01:31.690000
#
#                        Q2                     Q3           GrandPrix
# 81 0 days 00:01:31.200000 0 days 00:01:30.641000  Chinese Grand Prix
# 63 0 days 00:01:31.307000 0 days 00:01:30.723000  Chinese Grand Prix
# 4  0 days 00:01:30.787000 0 days 00:01:30.793000  Chinese Grand Prix
# 1  0 days 00:01:31.142000 0 days 00:01:30.817000  Chinese Grand Prix
# 44 0 days 00:01:31.501000 0 days 00:01:30.927000  Chinese Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_china_quali = laps[['Driver','LapNumber' ,'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_china_quali['GrandPrix']='Chinese Grand Prix'
sector_times_china_quali.head()
# Out:
#    Driver  LapNumber                LapTime            Sector1Time  \
# 1     PIA        2.0 0 days 00:01:31.591000 0 days 00:00:24.176000
# 4     PIA        5.0 0 days 00:01:31.927000 0 days 00:00:24.252000
# 9     PIA       10.0 0 days 00:01:31.200000 0 days 00:00:24.219000
# 12    PIA       13.0 0 days 00:01:31.245000 0 days 00:00:24.103000
# 15    PIA       16.0 0 days 00:01:30.703000 0 days 00:00:23.984000
#
#               Sector2Time            Sector3Time           GrandPrix
# 1  0 days 00:00:27.442000 0 days 00:00:39.973000  Chinese Grand Prix
# 4  0 days 00:00:27.538000 0 days 00:00:40.137000  Chinese Grand Prix
# 9  0 days 00:00:27.341000 0 days 00:00:39.640000  Chinese Grand Prix
# 12 0 days 00:00:27.315000 0 days 00:00:39.827000  Chinese Grand Prix
# 15 0 days 00:00:27.163000 0 days 00:00:39.556000  Chinese Grand Prix

# %%
session=fastf1.get_session(2025,'China','R')
session.load()
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '63', '1', '31', '12', '23', '87', '18', '55', '6', '30', '7', '5', '27', '22', '14', '16', '44', '10']

# %%
china_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
china_race['GrandPrix']='Chinese Grand Prix'
china_race.head()
# Out:
#     Position Abbreviation         TeamName                   Time    Status  \
# 81       1.0          PIA          McLaren 0 days 01:30:55.026000  Finished
# 4        2.0          NOR          McLaren 0 days 00:00:09.748000  Finished
# 63       3.0          RUS         Mercedes 0 days 00:00:11.097000  Finished
# 1        4.0          VER  Red Bull Racing 0 days 00:00:16.656000  Finished
# 31       5.0          OCO     Haas F1 Team 0 days 00:00:49.969000  Finished
#
#              GrandPrix
# 81  Chinese Grand Prix
# 4   Chinese Grand Prix
# 63  Chinese Grand Prix
# 1   Chinese Grand Prix
# 31  Chinese Grand Prix

# %%
session=fastf1.get_session(2025,'Japan','Q')
session.load()
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '63', '12', '6', '44', '23', '87', '10', '55', '14', '30', '22', '27', '5', '31', '7', '18']

# %%
japan_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
japan_quali['GrandPrix']='Japanese Grand Prix'
japan_quali.head()
# Out:
#     Position Abbreviation         TeamName                     Q1  \
# 1        1.0          VER  Red Bull Racing 0 days 00:01:27.943000
# 4        2.0          NOR          McLaren 0 days 00:01:27.845000
# 81       3.0          PIA          McLaren 0 days 00:01:27.687000
# 16       4.0          LEC          Ferrari 0 days 00:01:27.920000
# 63       5.0          RUS         Mercedes 0 days 00:01:27.843000
#
#                        Q2                     Q3            GrandPrix
# 1  0 days 00:01:27.502000 0 days 00:01:26.983000  Japanese Grand Prix
# 4  0 days 00:01:27.146000 0 days 00:01:26.995000  Japanese Grand Prix
# 81 0 days 00:01:27.507000 0 days 00:01:27.027000  Japanese Grand Prix
# 16 0 days 00:01:27.555000 0 days 00:01:27.299000  Japanese Grand Prix
# 63 0 days 00:01:27.400000 0 days 00:01:27.318000  Japanese Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_japan_quali = laps[['Driver', 'LapNumber','LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_japan_quali['GrandPrix']='Japanese Grand Prix'
sector_times_japan_quali.head()
# Out:
#    Driver  LapNumber                LapTime            Sector1Time  \
# 1     VER        2.0 0 days 00:01:28.360000 0 days 00:00:30.856000
# 4     VER        5.0 0 days 00:01:27.943000 0 days 00:00:30.696000
# 7     VER        8.0 0 days 00:01:27.502000 0 days 00:00:30.510000
# 12    VER       13.0 0 days 00:01:27.278000 0 days 00:00:30.463000
# 15    VER       16.0 0 days 00:01:26.983000 0 days 00:00:30.387000
#
#               Sector2Time            Sector3Time            GrandPrix
# 1  0 days 00:00:40.015000 0 days 00:00:17.489000  Japanese Grand Prix
# 4  0 days 00:00:39.718000 0 days 00:00:17.529000  Japanese Grand Prix
# 7  0 days 00:00:39.641000 0 days 00:00:17.351000  Japanese Grand Prix
# 12 0 days 00:00:39.463000 0 days 00:00:17.352000  Japanese Grand Prix
# 15 0 days 00:00:39.355000 0 days 00:00:17.241000  Japanese Grand Prix

# %%
session=fastf1.get_session(2025,'Japan','R')
session.load()
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '63', '12', '44', '6', '23', '87', '14', '22', '10', '55', '7', '27', '30', '31', '5', '18']

# %%
japan_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
japan_race['GrandPrix']='Japanese Grand Prix'
japan_race.head()
# Out:
#     Position Abbreviation         TeamName                   Time    Status  \
# 1        1.0          VER  Red Bull Racing 0 days 01:22:06.983000  Finished
# 4        2.0          NOR          McLaren 0 days 00:00:01.423000  Finished
# 81       3.0          PIA          McLaren 0 days 00:00:02.129000  Finished
# 16       4.0          LEC          Ferrari 0 days 00:00:16.097000  Finished
# 63       5.0          RUS         Mercedes 0 days 00:00:17.362000  Finished
#
#               GrandPrix
# 1   Japanese Grand Prix
# 4   Japanese Grand Prix
# 81  Japanese Grand Prix
# 16  Japanese Grand Prix
# 63  Japanese Grand Prix

# %%
session=fastf1.get_session(2025,'Bahrain','Q')
session.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '63', '16', '12', '10', '4', '1', '55', '44', '22', '7', '6', '14', '31', '23', '27', '30', '5', '18', '87']

# %%
bahrain_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
bahrain_quali['GrandPrix']='Bahrain Grand Prix'
bahrain_quali.head()
# Out:
#     Position Abbreviation  TeamName                     Q1  \
# 81       1.0          PIA   McLaren 0 days 00:01:31.392000
# 63       2.0          RUS  Mercedes 0 days 00:01:31.494000
# 16       3.0          LEC   Ferrari 0 days 00:01:31.454000
# 12       4.0          ANT  Mercedes 0 days 00:01:31.415000
# 10       5.0          GAS    Alpine 0 days 00:01:31.462000
#
#                        Q2                     Q3           GrandPrix
# 81 0 days 00:01:30.454000 0 days 00:01:29.841000  Bahrain Grand Prix
# 63 0 days 00:01:30.664000 0 days 00:01:30.009000  Bahrain Grand Prix
# 16 0 days 00:01:30.724000 0 days 00:01:30.175000  Bahrain Grand Prix
# 12 0 days 00:01:30.716000 0 days 00:01:30.213000  Bahrain Grand Prix
# 10 0 days 00:01:30.643000 0 days 00:01:30.216000  Bahrain Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_bahrain_quali = laps[['Driver', 'LapNumber','LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_bahrain_quali['GrandPrix']='Bahrain Grand Prix'
sector_times_bahrain_quali.head()
# Out:
#    Driver  LapNumber                LapTime            Sector1Time  \
# 1     PIA        2.0 0 days 00:01:31.392000 0 days 00:00:29.287000
# 7     PIA        8.0 0 days 00:01:30.454000 0 days 00:00:28.883000
# 10    PIA       11.0 0 days 00:01:30.233000 0 days 00:00:28.902000
# 13    PIA       14.0 0 days 00:01:29.841000 0 days 00:00:28.784000
# 16    RUS        2.0 0 days 00:01:31.941000 0 days 00:00:29.278000
#
#               Sector2Time            Sector3Time           GrandPrix
# 1  0 days 00:00:39.300000 0 days 00:00:22.805000  Bahrain Grand Prix
# 7  0 days 00:00:38.853000 0 days 00:00:22.718000  Bahrain Grand Prix
# 10 0 days 00:00:38.771000 0 days 00:00:22.560000  Bahrain Grand Prix
# 13 0 days 00:00:38.574000 0 days 00:00:22.483000  Bahrain Grand Prix
# 16 0 days 00:00:39.722000 0 days 00:00:22.941000  Bahrain Grand Prix

# %%
session=fastf1.get_session(2025,'Bahrain','R')
session.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 63: Lap timing integrity check failed for 3 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
bahrain_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
bahrain_race['GrandPrix']='Bahrain Grand Prix'
bahrain_race.head()
# Out:
#     Position Abbreviation  TeamName                   Time    Status  \
# 81       1.0          PIA   McLaren 0 days 01:35:39.435000  Finished
# 63       2.0          RUS  Mercedes 0 days 00:00:15.499000  Finished
# 4        3.0          NOR   McLaren 0 days 00:00:16.273000  Finished
# 16       4.0          LEC   Ferrari 0 days 00:00:19.679000  Finished
# 44       5.0          HAM   Ferrari 0 days 00:00:27.993000  Finished
#
#              GrandPrix
# 81  Bahrain Grand Prix
# 63  Bahrain Grand Prix
# 4   Bahrain Grand Prix
# 16  Bahrain Grand Prix
# 44  Bahrain Grand Prix

# %%
session=fastf1.get_session(2025,'Saudi Arabia','Q')
session.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '63', '16', '12', '55', '44', '22', '10', '4', '23', '30', '14', '6', '87', '18', '7', '27', '31', '5']

# %%
saudi_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
saudi_quali['GrandPrix']='Saudi Arabian Grand Prix'
saudi_quali.head()
# Out:
#     Position Abbreviation         TeamName                     Q1  \
# 1        1.0          VER  Red Bull Racing 0 days 00:01:27.778000
# 81       2.0          PIA          McLaren 0 days 00:01:27.901000
# 63       3.0          RUS         Mercedes 0 days 00:01:28.282000
# 16       4.0          LEC          Ferrari 0 days 00:01:28.552000
# 12       5.0          ANT         Mercedes 0 days 00:01:28.128000
#
#                        Q2                     Q3                 GrandPrix
# 1  0 days 00:01:27.529000 0 days 00:01:27.294000  Saudi Arabian Grand Prix
# 81 0 days 00:01:27.545000 0 days 00:01:27.304000  Saudi Arabian Grand Prix
# 63 0 days 00:01:27.599000 0 days 00:01:27.407000  Saudi Arabian Grand Prix
# 16 0 days 00:01:27.866000 0 days 00:01:27.670000  Saudi Arabian Grand Prix
# 12 0 days 00:01:27.798000 0 days 00:01:27.866000  Saudi Arabian Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_saudi_quali = laps[['Driver', 'LapNumber','LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_saudi_quali['GrandPrix']='Saudi Arabian Grand Prix'
sector_times_saudi_quali.head()
# Out:
#    Driver  LapNumber                LapTime            Sector1Time  \
# 1     VER        2.0 0 days 00:01:28.148000 0 days 00:00:31.970000
# 4     VER        5.0 0 days 00:01:27.778000 0 days 00:00:31.874000
# 7     VER        8.0 0 days 00:01:27.529000 0 days 00:00:31.710000
# 10    VER       11.0 0 days 00:01:27.940000 0 days 00:00:32.054000
# 14    VER       15.0 0 days 00:01:27.559000 0 days 00:00:31.829000
#
#               Sector2Time            Sector3Time                 GrandPrix
# 1  0 days 00:00:27.841000 0 days 00:00:28.337000  Saudi Arabian Grand Prix
# 4  0 days 00:00:27.813000 0 days 00:00:28.091000  Saudi Arabian Grand Prix
# 7  0 days 00:00:27.726000 0 days 00:00:28.093000  Saudi Arabian Grand Prix
# 10 0 days 00:00:27.764000 0 days 00:00:28.122000  Saudi Arabian Grand Prix
# 14 0 days 00:00:27.714000 0 days 00:00:28.016000  Saudi Arabian Grand Prix

# %%
session=fastf1.get_session(2025,'Saudi Arabia','R')
session.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '1', '16', '4', '63', '12', '44', '55', '23', '6', '14', '30', '87', '31', '27', '18', '7', '5', '22', '10']

# %%
saudi_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
saudi_race['GrandPrix']='Saudi Arabian Grand Prix'
saudi_race.head()
# Out:
#     Position Abbreviation         TeamName                   Time    Status  \
# 81       1.0          PIA          McLaren 0 days 01:21:06.758000  Finished
# 1        2.0          VER  Red Bull Racing 0 days 00:00:02.843000  Finished
# 16       3.0          LEC          Ferrari 0 days 00:00:08.104000  Finished
# 4        4.0          NOR          McLaren 0 days 00:00:09.196000  Finished
# 63       5.0          RUS         Mercedes 0 days 00:00:27.236000  Finished
#
#                    GrandPrix
# 81  Saudi Arabian Grand Prix
# 1   Saudi Arabian Grand Prix
# 16  Saudi Arabian Grand Prix
# 4   Saudi Arabian Grand Prix
# 63  Saudi Arabian Grand Prix

# %%
session=fastf1.get_session(2025,'Miami','Q')
session.load()
# Out:
# core           INFO 	Loading data for Miami Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '12', '81', '63', '55', '23', '16', '31', '22', '6', '44', '5', '7', '30', '27', '14', '10', '18', '87']

# %%
miami_quali=session.results[['Position', 'Abbreviation','TeamName', 'Q1', 'Q2', 'Q3']]
miami_quali['GrandPrix']='Miami Grand Prix'
miami_quali.head()
# Out:
#     Position Abbreviation         TeamName                     Q1  \
# 1        1.0          VER  Red Bull Racing 0 days 00:01:26.870000
# 4        2.0          NOR          McLaren 0 days 00:01:26.955000
# 12       3.0          ANT         Mercedes 0 days 00:01:27.077000
# 81       4.0          PIA          McLaren 0 days 00:01:27.006000
# 63       5.0          RUS         Mercedes 0 days 00:01:27.014000
#
#                        Q2                     Q3         GrandPrix
# 1  0 days 00:01:26.643000 0 days 00:01:26.204000  Miami Grand Prix
# 4  0 days 00:01:26.499000 0 days 00:01:26.269000  Miami Grand Prix
# 12 0 days 00:01:26.606000 0 days 00:01:26.271000  Miami Grand Prix
# 81 0 days 00:01:26.269000 0 days 00:01:26.375000  Miami Grand Prix
# 63 0 days 00:01:26.575000 0 days 00:01:26.385000  Miami Grand Prix

# %%
laps = session.laps.pick_quicklaps()
sector_times_miami_quali = laps[['Driver', 'LapNumber','LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']]
sector_times_miami_quali['GrandPrix']='Miami Grand Prix'
sector_times_miami_quali.head()
# Out:
#    Driver  LapNumber                LapTime            Sector1Time  \
# 1     VER        2.0 0 days 00:01:27.573000 0 days 00:00:28.784000
# 4     VER        5.0 0 days 00:01:26.870000 0 days 00:00:28.413000
# 7     VER        8.0 0 days 00:01:26.643000 0 days 00:00:28.345000
# 10    VER       11.0 0 days 00:01:26.654000 0 days 00:00:28.339000
# 13    VER       14.0 0 days 00:01:26.492000 0 days 00:00:28.268000
#
#               Sector2Time            Sector3Time         GrandPrix
# 1  0 days 00:00:33.733000 0 days 00:00:25.056000  Miami Grand Prix
# 4  0 days 00:00:33.450000 0 days 00:00:25.007000  Miami Grand Prix
# 7  0 days 00:00:33.309000 0 days 00:00:24.989000  Miami Grand Prix
# 10 0 days 00:00:33.405000 0 days 00:00:24.910000  Miami Grand Prix
# 13 0 days 00:00:33.245000 0 days 00:00:24.979000  Miami Grand Prix

# %%
session=fastf1.get_session(2025,'Miami','R')
session.load()
# Out:
# core           INFO 	Loading data for Miami Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 81 completed the race distance 00:00.036000 before the recorded end of the session.
# ...

# %%
miami_race = session.results[['Position', 'Abbreviation', 'TeamName', 'Time', 'Status']]
miami_race['GrandPrix']='Miami Grand Prix'
miami_race.head()
# Out:
#     Position Abbreviation         TeamName                   Time    Status  \
# 81       1.0          PIA          McLaren 0 days 01:28:51.587000  Finished
# 4        2.0          NOR          McLaren 0 days 00:00:04.630000  Finished
# 63       3.0          RUS         Mercedes 0 days 00:00:37.644000  Finished
# 1        4.0          VER  Red Bull Racing 0 days 00:00:39.956000  Finished
# 23       5.0          ALB         Williams 0 days 00:00:48.067000  Finished
#
#            GrandPrix
# 81  Miami Grand Prix
# 4   Miami Grand Prix
# 63  Miami Grand Prix
# 1   Miami Grand Prix
# 23  Miami Grand Prix

# %%
aus_quali=aus_quali[(aus_quali['Abbreviation']=='NOR')|(aus_quali['Abbreviation']=='PIA')]
china_quali=china_quali[(china_quali['Abbreviation']=='NOR')|(china_quali['Abbreviation']=='PIA')]
japan_quali=japan_quali[(japan_quali['Abbreviation']=='NOR')|(japan_quali['Abbreviation']=='PIA')]
bahrain_quali=bahrain_quali[(bahrain_quali['Abbreviation']=='NOR')|(bahrain_quali['Abbreviation']=='PIA')]
saudi_quali=saudi_quali[(saudi_quali['Abbreviation']=='NOR')|(saudi_quali['Abbreviation']=='PIA')]
miami_quali=miami_quali[(miami_quali['Abbreviation']=='NOR')|(miami_quali['Abbreviation']=='PIA')]

# %%
sector_times_aus_quali=sector_times_aus_quali[(sector_times_aus_quali['Driver']=='NOR')|(sector_times_aus_quali['Driver']=='PIA')]
sector_times_china_quali=sector_times_china_quali[(sector_times_china_quali['Driver']=='NOR')|(sector_times_china_quali['Driver']=='PIA')]
sector_times_japan_quali=sector_times_japan_quali[(sector_times_japan_quali['Driver']=='NOR')|(sector_times_japan_quali['Driver']=='PIA')]
sector_times_bahrain_quali=sector_times_bahrain_quali[(sector_times_bahrain_quali['Driver']=='NOR')|(sector_times_bahrain_quali['Driver']=='PIA')]
sector_times_saudi_quali=sector_times_saudi_quali[(sector_times_saudi_quali['Driver']=='NOR')|(sector_times_saudi_quali['Driver']=='PIA')]
sector_times_miami_quali=sector_times_miami_quali[(sector_times_miami_quali['Driver']=='NOR')|(sector_times_miami_quali['Driver']=='PIA')]

# %%
aus_race=aus_race[(aus_race['Abbreviation']=='NOR')|(aus_race['Abbreviation']=='PIA')]
china_race=china_race[(china_race['Abbreviation']=='NOR')|(china_race['Abbreviation']=='PIA')]
japan_race=japan_race[(japan_race['Abbreviation']=='NOR')|(japan_race['Abbreviation']=='PIA')]
bahrain_race=bahrain_race[(bahrain_race['Abbreviation']=='NOR')|(bahrain_race['Abbreviation']=='PIA')]
saudi_race=saudi_race[(saudi_race['Abbreviation']=='NOR')|(saudi_race['Abbreviation']=='PIA')]
miami_race=miami_race[(miami_race['Abbreviation']=='NOR')|(miami_race['Abbreviation']=='PIA')]

# %%
import pandas as pd

# %%
aus_quali.to_csv('aus_quali.csv')
china_quali.to_csv('china_quali.csv')
japan_quali.to_csv('japan_quali.csv')
bahrain_quali.to_csv('bahrain_quali.csv')
saudi_quali.to_csv('saudi_quali.csv')
miami_quali.to_csv('miami_quali.csv')

# %%
sector_times_aus_quali.to_csv('sector_times_aus_quali.csv')
sector_times_china_quali.to_csv('sector_times_china_quali.csv')
sector_times_japan_quali.to_csv('sector_times_japan_quali.csv')
sector_times_bahrain_quali.to_csv('sector_times_bahrain_quali.csv')
sector_times_saudi_quali.to_csv('sector_times_saudi_quali.csv')
sector_times_miami_quali.to_csv('sector_times_miami_quali.csv')

# %%
aus_race.to_csv('aus_race.csv')
china_race.to_csv('china_race.csv')
japan_race.to_csv('japan_race.csv')
bahrain_race.to_csv('bahrain_race.csv')
saudi_race.to_csv('saudi_race.csv')
miami_race.to_csv('miami_race.csv')

# %%
results['Time'] = results['Time'].apply(lambda x: str(x).split()[-1])
results.head()
# Out:
# C:\Users\dorot\AppData\Local\Temp\ipykernel_15724\980954602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['Time'] = results['Time'].apply(lambda x: str(x).split()[-1])
#     Position DriverNumber Abbreviation         TeamName             Time  \
# 4        1.0            4          NOR          McLaren  01:42:06.304000
# 1        2.0            1          VER  Red Bull Racing  00:00:00.895000
# 63       3.0           63          RUS         Mercedes  00:00:08.481000
# 12       4.0           12          ANT         Mercedes  00:00:10.135000
# 23       5.0           23          ALB         Williams  00:00:12.773000
#
#       Status
# 4   Finished
# 1   Finished
# 63  Finished
# 12  Finished
# 23  Finished
